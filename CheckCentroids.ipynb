# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
import gudhi
import numpy as np
from matplotlib.patches import Polygon
gudhi.persistence_graphical_tools._gudhi_matplotlib_use_tex=False

from utils import load_data

# %%
gdf = load_data('025-imperial')
gdf.head()
# Out:
#                                                      geometry  \
# pct16
# 025-281045  POLYGON ((-115.65670 32.69474, -115.65216 32.6...
# 025-245228  POLYGON ((-115.56954 32.77721, -115.57100 32.7...
# 025-245226  POLYGON ((-115.56105 32.77390, -115.56100 32.7...
# 025-245225  POLYGON ((-115.55464 32.77838, -115.55681 32.7...
# 025-245224  MULTIPOLYGON (((-115.54322 32.77380, -115.5494...
#
#                                centroid  abs_clinton  abs_trump  per_clinton  \
# pct16
# 025-281045  POINT (-115.58976 32.69063)         13.0        0.0     1.000000
# 025-245228  POINT (-115.57661 32.77945)        314.0      184.0     0.630522
# 025-245226  POINT (-115.56787 32.77316)        623.0      377.0     0.623000
# 025-245225  POINT (-115.55789 32.77993)        119.0       56.0     0.680000
# 025-245224  POINT (-115.55360 32.77472)        717.0      193.0     0.787912
#
#             per_trump
# pct16
# 025-281045   0.000000
# 025-245228   0.369478
# 025-245226   0.377000
# ...

# %%
ax = gdf.plot("per_clinton", legend=True, cmap='RdBu', figsize=(20,12))

# %% [markdown]
# # Check if centroids are valid

# %%
ax = gdf.plot(None, legend=True, cmap="tab20", figsize=(20,12))
gdf["centroid"].plot(ax=ax, color="white", markersize=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Feature maps
